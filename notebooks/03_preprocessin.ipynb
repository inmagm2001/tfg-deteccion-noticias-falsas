# %% [markdown]
# # Preprocesamiento de Texto para la Clasificación de Noticias
#
# Este notebook tiene como objetivo aplicar un preprocesamiento exhaustivo sobre un conjunto de datos textuales, con el fin de preparar los textos para su posterior análisis y clasificación.
#
# ### Importación de librerías

# %%
import sys
import pandas as pd
sys.path.append('../src')  # Añades esa carpeta al path
from preprocessing import preprocess
from preprocessing import recortar_texto
# Out:
# [nltk_data] Downloading package punkt to /home/inma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/inma/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/inma/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Ruta a los datos 
path = '../data/processed/noticias_tema.csv' 

# Cargar CSVs
df = pd.read_csv(path)

df.drop(columns=['title_length', 'no_verbs'], inplace=True)
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 61844  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 61845  Russians steal research on Trump in hack of U....
# 61846   WATCH: Giuliani Demands That Democrats Apolog...
# 61847  Migrants Refuse To Leave Train At Refugee Camp...
# 61848  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label news_type  \
# 0      No comment is expected from Barack Obama Membe...      1      Real
# 1       Now, most of the demonstrators gathered last ...      1      Real
# 2      A dozen politically active pastors came here f...      0     Falsa
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1      Real
# 4      All we can say on this one is it s about time ...      1      Real
# ...                                                  ...    ...       ...
# 61844  An email released by WikiLeaks on Sunday appea...      1      Real
# 61845  WASHINGTON (Reuters) - Hackers believed to be ...      0     Falsa
# 61846  You know, because in fantasyland Republicans n...      1      Real
# 61847  Migrants Refuse To Leave Train At Refugee Camp...      0     Falsa
# 61848  MEXICO CITY (Reuters) - Donald Trump’s combati...      0     Falsa
#
#                                                sentences lang  Cluster  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...   en        5
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...   en        5
# 2      Bobby Jindal, raised Hindu, uses story of Chri...   en        5
# 3      SATAN 2: Russia unvelis an image of its terrif...   en        0
# 4      About Time! Christian Group Sues Amazon and SP...   en        5
# ...                                                  ...  ...      ...
# 61844  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...   en        1
# 61845  Russians steal research on Trump in hack of U....   en        1
# 61846  WATCH: Giuliani Demands That Democrats Apologi...   en        4
# 61847  Migrants Refuse To Leave Train At Refugee Camp...   en        5
# 61848  Trump tussle gives unpopular Mexican leader mu...   en        4
#
#        category
# 0      sociedad
# 1      sociedad
# 2      sociedad
# 3      gobierno
# 4      sociedad
# ...         ...
# 61844   clinton
# 61845   clinton
# 61846     trump
# 61847  sociedad
# 61848     trump
#
# [61849 rows x 8 columns]

# %%
df['title_length'] = df['title'].apply(lambda t: len(str(t).split()))

# %%
df['title'] = df['title'].apply(preprocess)
df
# Out:
#                                                    title  \
# 0      law enforcement high alert following threat co...
# 1      unbelievable exclamationtoken obamas attorney ...
# 2      bobby jindal raised hindu us story christian c...
# 3      satan russia unvelis image terrifying new supe...
# 4      time exclamationtoken christian group sue amaz...
# ...                                                  ...
# 61844  wikileaks email show clinton foundation fund u...
# 61845  russian steal research trump hack u democratic...
# 61846  watch giuliani demand democrat apologize trump...
# 61847    migrant refuse leave train refugee camp hungary
# 61848  trump tussle give unpopular mexican leader muc...
#
#                                                     text  label news_type  \
# 0      No comment is expected from Barack Obama Membe...      1      Real
# 1       Now, most of the demonstrators gathered last ...      1      Real
# 2      A dozen politically active pastors came here f...      0     Falsa
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1      Real
# 4      All we can say on this one is it s about time ...      1      Real
# ...                                                  ...    ...       ...
# 61844  An email released by WikiLeaks on Sunday appea...      1      Real
# 61845  WASHINGTON (Reuters) - Hackers believed to be ...      0     Falsa
# 61846  You know, because in fantasyland Republicans n...      1      Real
# 61847  Migrants Refuse To Leave Train At Refugee Camp...      0     Falsa
# 61848  MEXICO CITY (Reuters) - Donald Trump’s combati...      0     Falsa
#
#                                                sentences lang  Cluster  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...   en        5
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...   en        5
# 2      Bobby Jindal, raised Hindu, uses story of Chri...   en        5
# 3      SATAN 2: Russia unvelis an image of its terrif...   en        0
# 4      About Time! Christian Group Sues Amazon and SP...   en        5
# ...                                                  ...  ...      ...
# 61844  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...   en        1
# 61845  Russians steal research on Trump in hack of U....   en        1
# 61846  WATCH: Giuliani Demands That Democrats Apologi...   en        4
# 61847  Migrants Refuse To Leave Train At Refugee Camp...   en        5
# 61848  Trump tussle gives unpopular Mexican leader mu...   en        4
#
#        category  title_length
# 0      sociedad            18
# 1      sociedad            18
# 2      sociedad            16
# 3      gobierno            16
# 4      sociedad            13
# ...         ...           ...
# 61844   clinton            15
# 61845   clinton            11
# 61846     trump            10
# 61847  sociedad            10
# 61848     trump            10
#
# [61849 rows x 9 columns]

# %%
df['text_length'] = df['text'].apply(lambda t: len(str(t).split()))
df['text'] = df['text'].apply(preprocess)
df['text'] = df['text'].apply(recortar_texto)
df
# Out:
#                                                    title  \
# 0      law enforcement high alert following threat co...
# 1      unbelievable exclamationtoken obamas attorney ...
# 2      bobby jindal raised hindu us story christian c...
# 3      satan russia unvelis image terrifying new supe...
# 4      time exclamationtoken christian group sue amaz...
# ...                                                  ...
# 61844  wikileaks email show clinton foundation fund u...
# 61845  russian steal research trump hack u democratic...
# 61846  watch giuliani demand democrat apologize trump...
# 61847    migrant refuse leave train refugee camp hungary
# 61848  trump tussle give unpopular mexican leader muc...
#
#                                                     text  label news_type  \
# 0      no comment expected barack obama member fyf fu...      1      Real
# 1      most demonstrator gathered last night exercisi...      1      Real
# 2      dozen politically active pastor came private d...      0     Falsa
# 3      r sarmat missile dubbed satan replace s fly mi...      1      Real
# 4      all say one time someone sued southern poverty...      1      Real
# ...                                                  ...    ...       ...
# 61844  email released wikileaks sunday appears show f...      1      Real
# 61845  washington reuters hacker believed working rus...      0     Falsa
# 61846  know fantasyland republican never questioned c...      1      Real
# 61847  migrant refuse leave train refugee camp hungar...      0     Falsa
# 61848  mexico city reuters donald trump combative sty...      0     Falsa
#
#                                                sentences lang  Cluster  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...   en        5
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...   en        5
# 2      Bobby Jindal, raised Hindu, uses story of Chri...   en        5
# 3      SATAN 2: Russia unvelis an image of its terrif...   en        0
# 4      About Time! Christian Group Sues Amazon and SP...   en        5
# ...                                                  ...  ...      ...
# 61844  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...   en        1
# 61845  Russians steal research on Trump in hack of U....   en        1
# 61846  WATCH: Giuliani Demands That Democrats Apologi...   en        4
# 61847  Migrants Refuse To Leave Train At Refugee Camp...   en        5
# 61848  Trump tussle gives unpopular Mexican leader mu...   en        4
#
#        category  title_length  text_length
# 0      sociedad            18          871
# 1      sociedad            18           34
# 2      sociedad            16         1321
# 3      gobierno            16          329
# 4      sociedad            13          244
# ...         ...           ...          ...
# 61844   clinton            15          205
# 61845   clinton            11          735
# 61846     trump            10          604
# 61847  sociedad            10          477
# 61848     trump            10          559
#
# [61849 rows x 10 columns]

# %%
# Calcular longitudes con list comprehension
longitudes = df['text'].str.split().str.len()


print(longitudes)  # Output: [4, 12, 14, 7]
# Out:
# 0        300
# 1         22
# 2        300
# 3        185
# 4        147
#         ...
# 61844    121
# 61845    300
# 61846    300
# 61847    278
# 61848    300
# Name: text, Length: 61849, dtype: int64

# %%
df['total_length'] = df['title_length'] + df['text_length']
df.drop(columns=['sentences'], inplace=True)
df['sentences'] = df['title'] + ' ' + df['text']

# %%
df
# Out:
#                                                    title  \
# 0      law enforcement high alert following threat co...
# 1      unbelievable exclamationtoken obamas attorney ...
# 2      bobby jindal raised hindu us story christian c...
# 3      satan russia unvelis image terrifying new supe...
# 4      time exclamationtoken christian group sue amaz...
# ...                                                  ...
# 61844  wikileaks email show clinton foundation fund u...
# 61845  russian steal research trump hack u democratic...
# 61846  watch giuliani demand democrat apologize trump...
# 61847    migrant refuse leave train refugee camp hungary
# 61848  trump tussle give unpopular mexican leader muc...
#
#                                                     text  label news_type  \
# 0      no comment expected barack obama member fyf fu...      1      Real
# 1      most demonstrator gathered last night exercisi...      1      Real
# 2      dozen politically active pastor came private d...      0     Falsa
# 3      r sarmat missile dubbed satan replace s fly mi...      1      Real
# 4      all say one time someone sued southern poverty...      1      Real
# ...                                                  ...    ...       ...
# 61844  email released wikileaks sunday appears show f...      1      Real
# 61845  washington reuters hacker believed working rus...      0     Falsa
# 61846  know fantasyland republican never questioned c...      1      Real
# 61847  migrant refuse leave train refugee camp hungar...      0     Falsa
# 61848  mexico city reuters donald trump combative sty...      0     Falsa
#
#       lang  Cluster  category  title_length  text_length  total_length  \
# 0       en        5  sociedad            18          871           889
# 1       en        5  sociedad            18           34            52
# 2       en        5  sociedad            16         1321          1337
# 3       en        0  gobierno            16          329           345
# 4       en        5  sociedad            13          244           257
# ...    ...      ...       ...           ...          ...           ...
# 61844   en        1   clinton            15          205           220
# 61845   en        1   clinton            11          735           746
# 61846   en        4     trump            10          604           614
# 61847   en        5  sociedad            10          477           487
# 61848   en        4     trump            10          559           569
#
#                                                sentences
# 0      law enforcement high alert following threat co...
# 1      unbelievable exclamationtoken obamas attorney ...
# 2      bobby jindal raised hindu us story christian c...
# 3      satan russia unvelis image terrifying new supe...
# 4      time exclamationtoken christian group sue amaz...
# ...                                                  ...
# 61844  wikileaks email show clinton foundation fund u...
# 61845  russian steal research trump hack u democratic...
# 61846  watch giuliani demand democrat apologize trump...
# 61847  migrant refuse leave train refugee camp hungar...
# 61848  trump tussle give unpopular mexican leader muc...
#
# [61849 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# title           0
# text            0
# label           0
# news_type       0
# lang            0
# Cluster         0
# category        0
# title_length    0
# text_length     0
# total_length    0
# sentences       0
# dtype: int64

# %%
df.to_csv('../data/processed/listo.csv', index=False)
